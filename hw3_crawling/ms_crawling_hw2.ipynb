# %%
"""
크롤링할 url은 아래에 있습니다.
목표는 페이지, 별점, 리뷰글을 크롤링하는 것입니다.
보내드린 result_example.csv 파일과 같이 만들어서 코드와 함께 제출해주세요.
result_example.csv는 엑셀로 열면 깨질 수도 있으니 메모장에서 보시거나 파이썬으로 보시면 됩니다.(encoding: utf-8)
15페이지까지 크롤링해서 보내주시면 됩니다.

데이터 입출력은 csv, pandas 패키지 중에 편한 것을 선택하셔서 쓰시면 됩니다.
사용 예시를 살짝 적어놓았습니다. 안 따르셔도 돼요.
"""

from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
import csv
from urllib.error import URLError

# 크롤링할 url
# http://deal.11st.co.kr/product/SellerProductDetail.tmall?method=getProductReviewList&prdNo=87595509&page=1&pageTypCd=first&reviewDispYn=Y&isPreview=false&reviewOptDispYn=n&optSearchBtnAndGraphLayer=n&reviewBottomBtn=Y&openDetailContents=Y&pageSize=10&isIgnoreAuth=false&lctgrNo=1001369&leafCtgrNo=0&groupProductNo=0&groupFirstViewPrdNo=0&selNo=16674487#this






# # 크롤링한 파일 저장 이름
# file_name = 'result_example.csv'
#
# # csv 패키지 사용할 때, 저장 결과 파일 생성
# f = open(file_path + file_name, 'a', encoding='utf-8', newline='')
# result = csv.writer(f)
# # 첫 행은 열 이름을 써야할 것입니다.
# result.writerow(['페이지', '별점', '리뷰'])
#
# # pandas 사용할 때, 리스트에 모았다가 한번에 df로 만들 수 있습니다.
# page_num = []
# 둘 중 아무거나 상관없어요^^

# %%
def downloadhtml(url):
    try:
        html = urlopen(url).read()
    except URLError as e:
        print(e)
        
    bsObj = BeautifulSoup(html,"html.parser")
    
    return bsObj

# %%
# 크롤링한 파일 저장 경로
file_path = '/Users/yumunsang/Documents/2018summer/boaz/쇼핑몰+리뷰+크롤링/'
urlbefore = 'http://deal.11st.co.kr/product/SellerProductDetail.tmall?method=getProductReviewList&prdNo=87595509&page='
urlafter = '&pageTypCd=first&reviewDispYn=Y&isPreview=false&reviewOptDispYn=n&optSearchBtnAndGraphL'
star = []
review = []
page_num = []

# %%
page = 1

while page <= 15:
    nowurl = urlbefore + str(page) + urlafter
    bsObj = downloadhtml(nowurl)
    products = bsObj.findAll('div',{'class':'cfix'})
    revs = bsObj.findAll('a',{'id':'reviewContTxt'})
    
    for i in range(len(products)):
        try:
            st = products[i].find('span',{'class':'selr_star selr_star100'}).get_text()
            st = st.split(" ")[4][0]
        except AttributeError as e:
            st = 0
        
        star.append(st)
        
        rev = revs[i].get_text().strip()
        review.append(rev)
        
        page_num.append(page)
        
    page += 1

# %%
# csv 패키지 사용할 때, 저장 파일 닫기
file_name = 'ms_crawling_boaz.csv'


# pandas 사용할 때, 결과 정리
result = pd.DataFrame({'page': page_num, 'star': star, 'review': review},columns=['page','star','review'])
print(result)
# 결과 저장
result.to_csv(file_path+file_name, encoding='utf-8',index=False)
# Out:
#      page star                                             review
# 0       1    5  네이처 사무용의자를 첨에 받았을 때 내가 과연 잘 조립할 수 있을까 걱정했는데 이게...
# 1       1    5  사무실 의자가 자꾸 소리도 나고 불편해져서 \n 녹색창에서 컴퓨터 의자를 검색하다가...
# 2       1    0  중저가 제품중에선 최상의 의자라고 생각합니다. 먼저 가장 중요한 뛰어난 가성비! 괜...
# 3       1    5  총알배송이네여. 화요일 주문햐그 목요일에 받았네요 택배기사님 친절하셔서 감사했어요 ...
# 4       1    5  처음엔 좀 무겁다 느꼈지만 바닥 긁힘 전혀 없구요, 의자 쿠션 푹신하고 등받이 매쉬...
# 5       1    5  원래 비싸더라도 좋은브랜드 사려고햇엇는데 요의자 저렴하고 평도 좋고 많이들 사셔서 ...
# 6       1    0  일단 배송이 빨라서 좋았습니다. 물건도 괜찮은거 같구요. 아쉬운점은 물건을 보니 부...
# 7       1    5  조립도 쉽고 의자도 편합니다. 가격대비 대만족합니다. 공구 없이 맨손으로도 조립할 ...
# 8       1    0  가격대비는 좋은듯하나 제품의 마감이 조금 별로네요 까진부분도 있고 등쪽 부품은 모서...
# 9       1    0  내게 딱 필요한 기능만 포함해서 구매할 수 있어서 좋았고 조립 간편했고 내구성은 나...
# 10      2    0  가격만 보고 사는 의자여! 가격치고는 트튼하고 간단하게 슬 수 있어. 가성비가 좋은...
# 11      2    0  재질.마감.내구성은 보통 입니다. 문제는 기능이.. 의자 높이가 찔끔 조절됩니다.....
# 12      2    5  배송도 빠르고 가격대비 너무좋아요 등받이 쿠션은 성인한테는좋은데 12살 딸아이는 아...
# 13      2    0  배송은 주문한 다음 날 도착 상품의 상태는 특별한 이상없이 양호 설치는 꼽기만 하면...
# 14      2    5  가격대비 대만족합니다. 의자편하고 조립도 도구 필요없이 맨손으로 가능해서 좋습니다....
# 15      2    0  등받이가 너무 약합니다 특히 등판이 좌우로 잘 못버텨요 6시방향은 버티는데 5시 7...
# 16      2    0  여름에 사용하기 시원하고 디자인 깔끔하고 싼 가격이라 불편하지 않을까 걱정햇는데 전...
# 17      2    5  조립 완전 쉽구요 2분걸린듯? 생각했던거보다 의자 훨씬 조아요 쿠션도 푹신하고 등받...
# 18      2    0  가격다운 품질이군요 검품도 엉망이고요 허리가 배기고 각부분연결이 나사 한개로 다 되...
# 19      2    5  그린색으로 샀다가 의자 넘넘 좋아서 핑크로 하나 더 샀어요 이번엔 조립 몇초만에 뚝...
# 20      3    0  오프라인 의자 대비 반값이라 샀건만.. 의자 균형도 안맞고 불편하네요. 하루종일 앉...
# 21      3    0  배송이 하루도 안되서 완료^^ 플라스틱이 부러질까 걱정스럽기는 한데 편하다고하네요....
# 22      3    5  가성비 어느 것 과도 비교 할 수 없을 정도로 대단하네요. 조립도 엄청 쉽고 튼튼하...
# 23      3    5  가성비 굿. 조립도 뭐 간단하네요. 마감이 좀 거칠긴하지만 쓰는데 지장은 없습니다....
# 24      3    5           이가격에 이정도면 만족합니다 조립도 쉽고 관건은 얼마만에 덜렁거리느냐인데
# 25      3    0           상품 만족합니다 깔끔하고 좋네요 가격은 싼데 싸보이지 않고 의자도 편해요
# 26      3    5     시중가의 절반가격으로 구매했습니다. 착석감도 아주 뛰어나고 디자인도 잘 빠졌네요..
# 27      3    0   그럭저럭 쓸만한데 굳이 요추 등받이는 추가할 필요없을것 같네요 오히려 더 불편한듯...
# 28      3    5   조립도 어렵지 않고 내구성도 좋은 듯 합니다. 추후 필요시에 추가 구매 고려 중입니다.
# 29      3    0   가격에 맞는 수준이예요! 싸고 좋은 것 찾은 것이었는데 딱 그 정도입니다. 잘 써야죠!
# ..    ...  ...                                                ...
# 120    13    5  포토리뷰는 처음 써보네요. 그만큼 마음에 들어서 써봅니다ㅋ [테이큰 완성형-그레이 ...
# 121    13    0  배송은 이상없이 왔습니다. 조립은 거의 그냥꽂으면 되는 수준입니다. 저가의자라 큰기...
# 122    13    0  약 1년 4개월 정도 사용하였는데요 의자 가죽이 완전 ㅜㅜㅜ 다 갈라졌어요. 의자를...
# 123    13    5  일단 배송 단 하루만에 왔구요 배송 하시는분도 무거우실텐데 매우 친절하시더라구요 그...
# 124    13    0  사실 듀오백이니 허리 받침 의자니 하는 이름이 붙기 시작하면서 의자들의 가격은 기본...
# 125    13    5  저는 30대중반의 회사원입니다. 집에와서도 일을 해야 하기에 의자를 신경써서 바꾸었...
# 126    13    5  안녕하세요? 최근 마이홈 의자(모델명=3026[주니온]완성형+대요추+헤드,색상선택:...
# 127    13    5  컴퓨터 사면서 의자 책상구입하눈데 따로구입하느라 애먹었네여 같이 팔면좋을텐데.. 배...
# 128    13    5  친절문자까지 주시고... 조립도 그다지 어렵지 않고요. 아주 쉽습니다^^ 어디 몇군...
# 129    13    5  독서실 다니다가 이제 여름이라 날씨가 덥거나 비오거나 둘 중 하나일것같고...집이랑...
# 130    14    5  솔직히~ 의자업계 1위라는 광고를 보고 혹해서 구입하긴 하였습니다. 그런데 의자 업...
# 131    14    0  상품 수령후 조립하다보니 다리에 작은 스크래치가 있었지만 인테리어 소품도 아니고상관...
# 132    14    5  지금 사용하던 의자 등받이가 분리가 돼서 자꾸 양옆, 앞뒤로 움직이는 바람에 장시간...
# 133    14    5  한달 앉아보고 리뷰쓰려다가 너무 맘에들어서 일주일만에 리뷰씁니다 ㅎ 첨에 싼 의자를...
# 134    14    5  6/7에 시켰는데 9일 토요일 낮에 왔어요. 이정도면 배송일은 무난하네요~ 이런 큰...
# 135    14    5  매우 만족스러운 의자구매 후 나름대로 제품에 대한 평가를 해봅니다. 몇 시간을 들여...
# 136    14    5  의자가 부서졌었습니다... 그래서 새로운 의자를 마련하고자 찾다가 11번가에서 마이...
# 137    14    5  제가 인터넷에서 물건사고 구매확정 해본 적이 첨 인것 같아요 ㅎㅎ 연구실에 매일 너...
# 138    14    0  11번가에서 주문한 마이홈의자 주니온 완성형. 메쉬가 통풍 잘 되고 시원하다곤 들었...
# 139    14    0  전에도 한번 구매했던 제품이라 믿고 구매했는데 헤드레스트를 빼고 보내주셨네요ㅠ 헤드...
# 140    15    5  정말 만족하고 사용하고있습니다 지난20년간 앉아왔던 딱딱한 우드소재 의자는 재활용 ...
# 141    15    5  일단 받아보니 조립하기 쉽게 낱개 포장이 잘 되어 있었어요. 봐도 어찌 조립해야할지...
# 142    15    5  일단 배송은 빠른편이예요~ 입금하고 3일만에 받았구요 처음엔 투박해보이고 무거워보였...
# 143    15    5  주문 하루만에박스포장으로 흠없이 무사히 배송 받았습니다. 일단, 산뜻한 색상이 눈에...
# 144    15    5  책상이 유럽제라, 여기에 어울릴만한 의자를 찾다보니, 요추건강에 좋지 않은 디자인뿐...
# 145    15    5  1주일간 써보니 적당히 뒤로 기울며 등과 허리를 받쳐주는 기능이 일반적인 저렴한 의...
# 146    15    5  식탁의자로 쓰던걸 책상에 놓고 썼는데 오래 못앉아있겠더라고요. 편안한 의자 구매하려...
# 147    15    5  신혼때 샀던 의자가 2년반만에 망가져서 새로운 의자를 사기위해 이리저리 알아봤는데 ...
# 148    15    5  저렴한 가격에 의자 득템! 사진 상엔 남색으로 보이지만 블랙이예요 >0< 도착하자마...
# 149    15    5  왼쪽이 원래 쓰던 국민책상+국민의자.... 그저 단순히 예뻐서 샀지만 저거 2년 쓰...
#
# [150 rows x 3 columns]
